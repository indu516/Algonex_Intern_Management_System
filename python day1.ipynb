# %%
game = {
    "name": "cricket",
    "players" : ['indu','rani','lokesh'],
    'role': "batsman"
}

print(game)
# Out:
# {'name': 'cricket', 'players': ['indu', 'rani', 'lokesh'], 'role': 'batsman'}

# %%
# create a dictionary with our own details
from turtle import update


student = {
    "name":  'indu',
    'age': 22,
    'dob': '19-03-2004',
    'cgpa': 8.4,
    'role': 'intern',
    'doj': '21-01-2026',
    'batch_type': 'spark',
    'location': 'banglore',
    'amount': 500000,
    'skills': ['Python',"java","sql","communication"]
}
print(student['cgpa'])
print(student['role'])
print(student['skills'][2])
print({student.update({'cgpa': 9.0})})
print(student)
print({student.update({'intern_id': 12345, 'roll_no': 2314150})})
# Out:
# 8.4
# intern
# sql
# {None}
# {'name': 'indu', 'age': 22, 'dob': '19-03-2004', 'cgpa': 9.0, 'role': 'intern', 'doj': '21-01-2026', 'batch_type': 'spark', 'location': 'banglore', 'amount': 500000, 'skills': ['Python', 'java', 'sql', 'communication']}
# {None}
