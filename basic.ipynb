# %%
print("algonex is welcoming you to the world of programming")
# Out:
# algonex is welcoming you to the world of programming

# %%
print('algonex is welcoming you to the world of programming')
# Out:
# algonex is welcoming you to the world of programming

# %%
print("algonex is welcoming you to the world's of programming")
print("algonex\t is welcoming you to the world of programming")
print("algonex\n is welcoming you to the world of programming")
print("algonex\b is welcoming you to the world of programming")
print("algonex is welcoming\v you to the world of programming")
# Out:
# algonex is welcoming you to the world's of programming
# algonex	 is welcoming you to the world of programming
# algonex
#  is welcoming you to the world of programming
# algone is welcoming you to the world of programming
# algonex is welcoming you to the world of programming

# %%
T =100 # integer
T = 200.2 # float
T= "algonex" #string
T= True #boolean
T=None #none type
print(T)
# Out:
# None

# %%
numbers =[20,30,40,50]      #creating the list numbers
print(numbers)
data = [10,"algonex",20.5,True]    #list of different data types
print(data)
# Out:
# [20, 30, 40, 50]
# [10, 'algonex', 20.5, True]

# %%
fruits = ("apple","mango","grapes")    #tuples
print(fruits)
# Out:
# ('apple', 'mango', 'grapes')

# %%
T = {234,45,67,89,45,67,"algonex"}   #set 
print(T)
# Out:
# {67, 89, 234, 'algonex', 45}

# %%
T = {"Name":"indu","Age" : 20,"cource":"python"}
print(T)
# Out:
# {'Name': 'indu', 'Age': 20, 'cource': 'python'}

# %%
print("welcome to algonex! you joined at ")
# Out:
# welcome to algonex! you joined at

# %%
print("algonex\b it solutions is in marathahalli\n for python and data tracking with AI")
# Out:
# algonex it solutions is in marathahalli
#  for python and data tracking with AI

# %%
h = 2324150    # integer
j=float(h)    # converting integer to float

# int to string
h = str(h)
print(h, "type is",type(h))
# Out:
# 2324150.0 type is <class 'str'>

# %%
#float
h = 12.5
# float to int
h = int(h)
print(h, type(h))
# Out:
# 12 <class 'int'>

# %%
s = "              Algonex IT solutions"
s=s.strip()       #it removes spaces from both sides
s= s.rstrip()    # it removes spaces from ride sides
s = s.lstrip()   # it removes spaces from left sides
# str to int
# s = int(s)
# split - convert into list
s = s.split()
# str to tuple
s=tuple(s)
print(s)
s=list(s)
print(s)
# Out:
# ('Algonex', 'IT', 'solutions')
# ['Algonex', 'IT', 'solutions']

# %%
l = [2324150, 12.5, "Indu", True,[12,23,45,67,89]]
print(l)
h = [11,22,33,44,55,"Indu",[2,3,4,5,], True, 23.4]
print(h[4])
print(h[0:3])      # h[start:end-1] - slicing
# Out:
# [2324150, 12.5, 'Indu', True, [12, 23, 45, 67, 89]]
# 55
# [11, 22, 33]

# %%
k = [24,34,56,67,65,34,12,45,67,89]
#print(k[0:5])
print(k[0:5:3])
print(k[2::])
print(k[::2])
# Out:
# [24, 67]
# [56, 67, 65, 34, 12, 45, 67, 89]
# [24, 56, 65, 12, 67]

# %%
print(k)
k[2]=200
l = [123,23,2,3]
#k.append(l)
k.append(1000)
print(k)
# Out:
# [24, 34, 200, 67, 65, 34, 12, 45, 67, 89, [123, 23, 2, 3]]
# [24, 34, 200, 67, 65, 34, 12, 45, 67, 89, [123, 23, 2, 3], 1000]

# %%
k = [23,45,34,78,90,50,67,89]
k.append(100)  # single element is added at the end of the list
k.extend([70, 80])    # multiple elements are added at the end of the list
k.insert(2, 200)

# delete
k.remove(34)      # it removes the first occurence of 34
k.pop(6)            # it removes the element at index 6
del k[2]            # it removes the element at index 2
print(k)
# Out:
# [23, 45, 78, 90, 50, 89, 100, 70, 80]
